# %%
import psycopg
from psycopg.types.json import Jsonb
from psycopg.rows import dict_row

# %%
conn = psycopg.connect(
    host="localhost",
    port=5432,
    dbname="initdb", 
    user="admin",
    password="qwer123456",
)


print("连接成功:", conn.info.server_version)
# Out:
# 连接成功: 170010

# %%
with conn.cursor() as cur:
    cur.execute("""
        CREATE TABLE IF NOT EXISTS students (
            id      SERIAL PRIMARY KEY, 
            name    VARCHAR(50) NOT NULL,
            profile JSONB     
        )
    """)
conn.commit()
print("建表完成")
# Out:
# 建表完成

# %%
with conn.cursor() as cur:
    cur.execute(
        "INSERT INTO students (name, profile) VALUES (%s, %s)",
        ("Alice", Jsonb({"age": 20, "score": 88.5})),
    )

conn.commit() 
print("插入数据完成")
# Out:
# 插入数据完成

# %%
rows = [
    ("Carol", Jsonb({"age": 19, "score": 76.0})),
    ("Dave", Jsonb({"age": 23, "score": 82.5})),
    ("Eve", Jsonb({"age": 21, "score": 95.0})),
]
with conn.cursor() as cur:
    cur.executemany(
        "INSERT INTO students (name, profile) VALUES (%s, %s)",
        rows,
    )
conn.commit()
print(f"批量插入{len(rows)}条")
# Out:
# 批量插入3条

# %%
with conn.cursor() as cur:
    cur.execute("SELECT id, name, profile FROM students ORDER BY id")
    rows = cur.fetchall()

    columns = [d.name for d in cur.description]
    print("列名:", columns)
    for row in rows:
        print(row)  
        print(type(row))  # tuple
        print(type(row[2]))  # dict(JSONB)
        print()
# Out:
# 列名: ['id', 'name', 'profile']
# (1, 'Alice', {'age': 20, 'score': 90.0})
# <class 'tuple'>
# <class 'dict'>
#
# (2, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (3, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (5, 'Alice', {'age': 20, 'score': 90.0})
# <class 'tuple'>
# <class 'dict'>
#
# (6, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (7, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (9, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (10, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (12, 'Alice', {'age': 20, 'score': 90.0})
# <class 'tuple'>
# <class 'dict'>
#
# (13, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (14, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (16, 'Alice', {'age': 20, 'score': 90.0})
# <class 'tuple'>
# <class 'dict'>
#
# (17, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (18, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (20, 'Alice', {'age': 20, 'score': 90.0})
# <class 'tuple'>
# <class 'dict'>
#
# (21, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (22, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (24, 'Alice', {'age': 20, 'score': 90.0})
# <class 'tuple'>
# <class 'dict'>
#
# (25, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (26, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (28, 'Alice', {'age': 20, 'score': 90.0})
# <class 'tuple'>
# <class 'dict'>
#
# (29, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (30, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (32, 'Alice', {'age': 20, 'score': 90.0})
# <class 'tuple'>
# <class 'dict'>
#
# (33, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (34, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (36, 'Alice', {'age': 20, 'score': 88.5})
# <class 'tuple'>
# <class 'dict'>
#
# (37, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (38, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (39, 'Eve', {'age': 21, 'score': 95.0})
# <class 'tuple'>
# <class 'dict'>
#
# (40, 'Alice', {'age': 20, 'score': 88.5})
# <class 'tuple'>
# <class 'dict'>
#
# (41, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (42, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (43, 'Eve', {'age': 21, 'score': 95.0})
# <class 'tuple'>
# <class 'dict'>
#
# (44, 'Alice', {'age': 20, 'score': 88.5})
# <class 'tuple'>
# <class 'dict'>
#
# (45, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (46, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (47, 'Eve', {'age': 21, 'score': 95.0})
# <class 'tuple'>
# <class 'dict'>
#
# (48, 'Alice', {'age': 20, 'score': 88.5})
# <class 'tuple'>
# <class 'dict'>
#
# (49, 'Carol', {'age': 19, 'score': 76.0})
# <class 'tuple'>
# <class 'dict'>
#
# (50, 'Dave', {'age': 23, 'score': 82.5})
# <class 'tuple'>
# <class 'dict'>
#
# (51, 'Eve', {'age': 21, 'score': 95.0})
# <class 'tuple'>
# <class 'dict'>

# %%
with conn.cursor(row_factory=dict_row) as cur:
    cur.execute("SELECT id, name, profile FROM students ORDER BY id")
    for row in cur:
        print(row)
# Out:
# {'id': 1, 'name': 'Alice', 'profile': {'age': 20, 'score': 90.0}}
# {'id': 2, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 3, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 5, 'name': 'Alice', 'profile': {'age': 20, 'score': 90.0}}
# {'id': 6, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 7, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 9, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 10, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 12, 'name': 'Alice', 'profile': {'age': 20, 'score': 90.0}}
# {'id': 13, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 14, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 16, 'name': 'Alice', 'profile': {'age': 20, 'score': 90.0}}
# {'id': 17, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 18, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 20, 'name': 'Alice', 'profile': {'age': 20, 'score': 90.0}}
# {'id': 21, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 22, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 24, 'name': 'Alice', 'profile': {'age': 20, 'score': 90.0}}
# {'id': 25, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 26, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 28, 'name': 'Alice', 'profile': {'age': 20, 'score': 90.0}}
# {'id': 29, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 30, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 32, 'name': 'Alice', 'profile': {'age': 20, 'score': 90.0}}
# {'id': 33, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 34, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 36, 'name': 'Alice', 'profile': {'age': 20, 'score': 88.5}}
# {'id': 37, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 38, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 39, 'name': 'Eve', 'profile': {'age': 21, 'score': 95.0}}
# {'id': 40, 'name': 'Alice', 'profile': {'age': 20, 'score': 88.5}}
# {'id': 41, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 42, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 43, 'name': 'Eve', 'profile': {'age': 21, 'score': 95.0}}
# {'id': 44, 'name': 'Alice', 'profile': {'age': 20, 'score': 88.5}}
# {'id': 45, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 46, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 47, 'name': 'Eve', 'profile': {'age': 21, 'score': 95.0}}
# {'id': 48, 'name': 'Alice', 'profile': {'age': 20, 'score': 88.5}}
# {'id': 49, 'name': 'Carol', 'profile': {'age': 19, 'score': 76.0}}
# {'id': 50, 'name': 'Dave', 'profile': {'age': 23, 'score': 82.5}}
# {'id': 51, 'name': 'Eve', 'profile': {'age': 21, 'score': 95.0}}

# %%
with conn.cursor() as cur:
    cur.execute(
        "UPDATE students SET profile = jsonb_set(profile, '{score}', %s) WHERE name = %s",
        (Jsonb(90.0), "Alice"),
    )
    print("更新行数:", cur.rowcount)
    
    cur.execute("DELETE FROM students WHERE name = %s", ("Eve",))
    print("删除行数:", cur.rowcount)

conn.commit()
# Out:
# 更新行数: 12
# 删除行数: 4

# %%
try:
    with conn.cursor() as cur:
        # 第一条语句正常执行
        cur.execute(
            "UPDATE students SET profile = jsonb_set(profile, '{score}', %s) WHERE name = %s",
            (Jsonb(100.0), "Alice"),
        )
        print("更新行数:", cur.rowcount)

        # 第二条语句出错(列age不存在),触发异常
        cur.execute("UPDATE students SET age = %s WHERE name = %s", (18, "Carol"))

    conn.commit()
except Exception as e:
    # Roll back to the start of any pending transaction.
    conn.rollback()  
    print("发生异常,已回滚:", e)
# Out:
# 更新行数: 12
# 发生异常,已回滚: column "age" of relation "students" does not exist
# LINE 1: UPDATE students SET age = $1 WHERE name = $2
#                             ^

# %%
# 关闭连接
conn.close()
print("连接已关闭")
# Out:
# 连接已关闭
