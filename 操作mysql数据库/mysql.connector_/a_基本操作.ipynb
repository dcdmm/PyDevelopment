# %%
import mysql.connector as mysql

# %%
cnx = mysql.connect(
    host='localhost',
    port='19950',
    user='root',
    password='dsjk@186115!',
    database='amp',
    charset='utf8mb4'
    )
cursor = cnx.cursor()
query = ("SELECT id, city_name FROM ai_setting")

cursor.execute(query)  # 增删改查
results = cursor.fetchall()  # 数据
column_names = [desc[0] for desc in cursor.description]  # 列名
print(results)
print(column_names)
# Out:
# [(1, '深圳市'), (2, '深圳市'), (3, '深圳市'), (4, '深圳市'), (5, '深圳市'), (6, '北京市朝阳区'), (7, '广东省广州市越秀区'), (8, '山西省太原市迎泽区'), (9, '北京市大兴区'), (10, '广东省深圳市南山区'), (11, '云南省玉溪市红塔区'), (12, '山西省太原市小店区'), (13, '山西省运城市盐湖区'), (14, '江苏省宿迁市宿豫区'), (15, '北京市大兴区'), (16, '深圳市'), (17, '衢州市柯城区'), (19, '广东省深圳市罗湖区'), (20, '重庆市江北区'), (21, '重庆市江北区'), (22, '深圳市'), (23, '凉山彝族自治州美姑县'), (24, '江西省赣州市宁都县'), (25, '深圳市南山区'), (26, '浙江省台州市三门县'), (27, '广东省惠州市惠东县'), (28, '庆阳市西峰区'), (29, '广东省清远市连州市'), (30, '西安市莲湖区'), (31, '山西省太原市杏花岭区'), (32, '福建省福州市长乐区'), (33, '怀化市鹤城区'), (34, '广东省河源市源城区'), (35, '衢州市柯城区'), (36, '广西壮族自治区贺州市'), (37, '海南省海口市秀英区'), (38, '山西省太原市'), (40, '运城市盐湖区'), (41, '鞍山市千山区'), (42, '山西省晋中市榆次区'), (43, '湖北省孝感市孝南区'), (44, '江西省九江市修水县'), (45, '四川省成都市'), (46, '西安市新城区'), (47, '湖南省长沙市岳麓区'), (48, '辽宁省葫芦岛市兴城市'), (50, '辽宁省沈阳市浑南区'), (51, '山西省临汾市吉县'), (52, '江西省上饶市余干县'), (53, '山西省临汾市洪洞县'), (54, '湖南省长沙市望城区'), (55, '山西省晋中市榆次区'), (56, '黑龙江省哈尔滨市平房区'), (58, '怀化市溆浦县'), (59, '山西省吕梁市离石区'), (60, '湖北省十堰市丹江口市'), (61, '四川省阿坝藏族羌族自治州茂县'), (62, 
# ...

# %%
cnx.close()
